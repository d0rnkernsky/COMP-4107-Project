# %%
import utils as ut
import cv2 as cv
import matplotlib.pyplot as plt

# %%
paths = ['dataset/Aaron_Peirsol_0001.jpg', 'dataset/Aaron_Peirsol_0002.jpg']

img = cv.imread(paths[0])
img1 = cv.imread(paths[1])

face_rect = ut.detect_face_rect(img)
x, y, w,h = face_rect

face_rect1 = ut.detect_face_rect(img1)
x1, y1, w1, h1 = face_rect1


print(face_rect)
# Out:
# [ 70  68 114 114]

# %%
#cv.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
# Out:
# array([[[244, 245, 241],
#         [244, 245, 241],
#         [243, 244, 240],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        [[243, 244, 240],
#         [243, 244, 240],
#         [243, 244, 240],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        [[241, 242, 238],
#         [241, 242, 238],
#         [242, 243, 239],
#         ...,
#         [239, 239, 239],
#         [239, 239, 239],
#         [239, 239, 239]],
#
#        ...,
#
#        [[ 53,  44,  30],
#         [ 58,  48,  31],
#         [ 67,  53,  34],
#         ...,
#         [ 70,  56,  44],
#         [ 69,  55,  43],
#         [ 71,  57,  45]],
#
#        [[ 53,  46,  29],
#         [ 56,  49,  30],
#         [ 65,  52,  30],
#         ...,
#         [ 69,  55,  43],
#         [ 69,  55,  43],
#         [ 69,  55,  43]],
#
#        [[ 53,  47,  28],
#         [ 56,  49,  29],
#         [ 65,  53,  29],
#         ...,
#         [ 69,  55,  43],
#         [ 69,  55,  43],
#         [ 69,  55,  43]]], dtype=uint8)

# %%
plt.imshow(img)

# %%
pad = 9
n = 11
blurred = cv.GaussianBlur(img[x:x+w,y:y+h],(pad,pad), n)  
plt.imshow(blurred)

# %%
blurred_face = img.copy()
blurred_face[x:x+w,y:y+h] = blurred


#blurred face
plt.imshow(blurred_face)

# %%
blurred1 = cv.GaussianBlur(img1[x1:x1+w1,y1:y1+h1],(pad,pad), n)  
blurred_face1 = img1.copy()
blurred_face1[x1:x1+w1,y1:y1+h1] = blurred1


#blurred face
plt.imshow(blurred_face1)
